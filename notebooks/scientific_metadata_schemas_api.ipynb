# %% [markdown]
# # Scientific Metadata Schemas API
#
# Fetch Bioschemas and DataCite metadata from nmrXiv.

# %%
import os
from pprint import pprint

import requests
from dotenv import load_dotenv

load_dotenv()

BASE_URL = os.getenv("NMRXIV_BASE_URL", "https://nmrxiv.org").rstrip("/")
API_BASE = f"{BASE_URL}/api"

session = requests.Session()
session.headers.update({"Accept": "application/json", "Content-Type": "application/json"})

BASE_URL, API_BASE
# Out:
# ('https://dev.nmrxiv.org', 'https://dev.nmrxiv.org/api')

# %%
def api_request(method, path, **kwargs):
    url = f"{API_BASE}{path}"
    response = session.request(method, url, timeout=30, **kwargs)
    print(f"{response.request.method} {response.url} -> {response.status_code}")
    try:
        payload = response.json()
    except ValueError:
        payload = response.text
    if not response.ok:
        pprint(payload)
        response.raise_for_status()
    return payload


def bioschemas(public_id=None, username=None, project=None):
    if username and project:
        return api_request("GET", f"/v1/schemas/bioschemas/{username}/{project}")
    if public_id:
        return api_request("GET", f"/v1/schemas/bioschemas/{public_id}")
    return api_request("GET", "/v1/schemas/bioschemas/")


def datacite(public_id=None, username=None, project=None):
    if username and project:
        return api_request("GET", f"/v1/schemas/datacite/{username}/{project}")
    if public_id:
        return api_request("GET", f"/v1/schemas/datacite/{public_id}")
    return api_request("GET", "/v1/schemas/datacite/")

# %% [markdown]
# ## Retrieve Schema.org DataCatalog metadata for nmrXiv repository
# Generates comprehensive Schema.org DataCatalog metadata representing nmrXiv as a scientific data repository. This endpoint provides structured metadata that enhances repository discoverability in search engines, enables integration with scientific data aggregators, and supports FAIR data principles. The DataCatalog schema includes detailed information about the repository's scope, contributors, measurement techniques, and scientific ontology mappings for NMR spectroscopy data.

# %%
bioschemas_index = bioschemas()
bioschemas_index
# Out:
# GET https://dev.nmrxiv.org/api/v1/schemas/bioschemas/ -> 200
# {'@context': 'https://schema.org',
#  '@type': 'DataCatalog',
#  '@id': 'https://dev.nmrxiv.org',
#  'dct:conformsTo': [{'@type': 'CreativeWork',
#    '@id': 'https://schema.org/DataCatalog'}],
#  'description': 'NMRXIV is an open-access preprint repository for sharing and discovering nuclear magnetic resonance (NMR) spectroscopy data.',
#  'keywords': [{'@type': 'DefinedTerm',
#    'name': 'nuclear magnetic resonance spectroscopy',
#    'alternateName': ['NMR',
#     'NMR spectroscopy',
#     'nuclear magnetic resonance (NMR) spectroscopy'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0000591',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0000591'},
#   {'@type': 'DefinedTerm',
#    'name': 'pulsed nuclear magnetic resonance spectroscopy',
#    'alternateName': ['NMR',
#     'nuclear magnetic resonance spectroscopy',
#     'NMR spectroscopy'],
#    'url': 'https://ontobee.org/ontology/CHMO?iri=http://purl.obolibrary.org/obo/CHMO_0000613',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0000613'},
#   {'@type': 'DefinedTerm',
#    'name': 'one-dimensional nuclear magnetic resonance spectroscopy',
#    'alternateName': ['1D NMR spectroscopy',
#     '1-D NMR',
#     'one-dimensional nuclear magnetic resonance spectroscopy',
#     '1D NMR',
#     '1D nuclear magnetic resonance spectroscopy'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0000592',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0000592'},
#   {'@type': 'DefinedTerm',
#    'name': 'two-dimensional nuclear magnetic resonance spectroscopy',
#    'alternateName': ['2-D NMR',
#     '2D NMR',
#     'two-dimensional nuclear magnetic resonance spectroscopy',
#     '2D NMR spectroscopy',
#     'two-dimensional NMR',
#     '2D nuclear magnetic resonance'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0000598',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0000598'},
#   {'@type': 'DefinedTerm',
#    'name': 'correlation spectroscopy spectrum',
#    'alternateName': ['COSY spectra',
#     'COSY spectrum',
#     'COSY NMR spectrum',
#     'COSY NMR spectra'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0002450',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0002450'},
#   {'@type': 'DefinedTerm',
#    'name': 'heteronuclear single quantum coherence',
#    'alternateName': ['HSQC'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0000604',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0000604'},
#   {'@type': 'DefinedTerm',
#    'name': 'heteronuclear multiple bond coherence',
#    'alternateName': ['HMBC NMR', 'HMBC'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0000601',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0000601'},
#   {'@type': 'DefinedTerm',
#    'name': 'two-dimensional nuclear Overhauser enhancement spectrum',
#    'alternateName': ['2D NOESY-NMR spectrum',
#     '2D NOESY-NMR spectra',
#     '2D NOESY spectra',
#     '2D NOESY spectrum'],
#    'url': 'http://purl.obolibrary.org/obo/CHMO_0001171',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'Chemical Methods Ontology',
#     'url': 'http://purl.obolibrary.org/obo/chmo.owl'},
#    '@id': 'CHMO:0001171'},
#   {'@type': 'DefinedTerm',
#    'name': 'Bruker',
#    'alternateName': [],
#    'url': 'http://nmrML.org/nmrCV#NMR:1400256',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'nuclear magnetic resonance CV',
#     'url': 'http://nmrml.org/cv/'},
#    '@id': 'NMR:1400256'},
#   {'@type': 'DefinedTerm',
#    'name': 'JEOL',
#    'alternateName': [],
#    'url': 'http://nmrML.org/nmrCV#NMR:1400258',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'nuclear magnetic resonance CV',
#     'url': 'http://nmrml.org/cv/'},
#    '@id': 'NMR:1400258'},
#   {'@type': 'DefinedTerm',
#    'name': 'NMReDATA',
#    'alternateName': [],
#    'url': 'http://edamontology.org/format_3906',
#    'inDefinedTermSet': {'@type': 'DefinedTermSet',
#     'name': 'nuclear magnetic resonance CV',
#     'url': 'http://nmrml.org/cv/'},
#    '@id': 'format:3906'}],
#  'name': 'nmrXiv-dev',
#  'provider': {'@type': 'Organization',
#   'name': 'NFDI4Chem',
#   'url': 'https://www.nfdi4chem.de/'},
#  'url': 'https://dev.nmrxiv.org',
#  'license': 'https://mit-license.org/',
#  'contributor': [{'@type': 'Person',
#    'givenName': 'Annett',
#    'familyName': 'Schröter',
#    'email': 'annett.schroeter@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0000-0002-2542-0867'},
#   {'@type': 'Person', 'givenName': 'Christian', 'familyName': 'Popp'},
#   {'@type': 'Person',
#    'givenName': 'Christoph',
#    'familyName': 'Steinbeck',
#    'email': 'christoph.steinbeck@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0000-0001-6966-0814'},
#   {'@type': 'Person',
#    'givenName': 'Darina',
#    'familyName': 'Storozhuk',
#    'email': 'darina.storozhuk@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena'},
#   {'@type': 'Person',
#    'givenName': 'Guido',
#    'familyName': 'Pauli',
#    'affiliation': 'University of Illinois',
#    '@id': '0000-0003-1022-4326'},
#   {'@type': 'Person',
#    'givenName': 'Hamed',
#    'familyName': 'Musallam',
#    'email': 'hamed.musallam@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena'},
#   {'@type': 'Person',
#    'givenName': 'Johannes',
#    'familyName': 'Liermann',
#    'email': 'liermann@uni-mainz.de',
#    'affiliation': 'Johannes Gutenberg-Universität Mainz',
#    '@id': '0000-0003-2060-842X'},
#   {'@type': 'Person',
#    'givenName': 'Julien',
#    'familyName': 'Wist',
#    'affiliation': 'Murdoch University: Murdoch, WA, AU',
#    '@id': '0000-0002-3416-2572'},
#   {'@type': 'Person',
#    'givenName': 'Kohulan',
#    'familyName': 'Rajan',
#    'email': 'kohulan.rajan@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0000-0003-1066-7792'},
#   {'@type': 'Person',
#    'givenName': 'Luc',
#    'familyName': 'Patiny',
#    'affiliation': 'École Polytechnique Fédérale de Lausanne: Lausanne, VD, CH',
#    '@id': '0000-0002-4943-2643'},
#   {'@type': 'Person', 'givenName': 'Markus', 'familyName': 'Lange'},
#   {'@type': 'Person',
#    'givenName': 'Nazar',
#    'familyName': 'Stefaniuk',
#    '@id': '0000-0002-5870-8496'},
#   {'@type': 'Person',
#    'givenName': 'Nils',
#    'familyName': 'Schlörer',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0000-0002-0990-9582'},
#   {'@type': 'Person',
#    'givenName': 'Nisha',
#    'familyName': 'Sharma',
#    'email': 'nisha.sharma@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0009-0006-4755-1039'},
#   {'@type': 'Person',
#    'givenName': 'Noura',
#    'familyName': 'Rayya',
#    'email': 'noura.rayya@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0009-0001-5998-5030'},
#   {'@type': 'Person', 'givenName': 'Pascal', 'familyName': 'Scherreiks'},
#   {'@type': 'Person',
#    'givenName': 'Stefan',
#    'familyName': 'Kuhn',
#    'affiliation': 'University of Tartu, Tartu',
#    '@id': '0000-0002-5990-4157'},
#   {'@type': 'Person',
#    'givenName': 'Steffen',
#    'familyName': 'Neumann',
#    'affiliation': 'Leibniz-Institut für Pflanzenbiochemie, Halle',
#    '@id': '0000-0002-7899-7192'},
#   {'@type': 'Person',
#    'givenName': 'Tillmann',
#    'familyName': 'Fischer',
#    'affiliation': 'Leibniz-Institut für Pflanzenbiochemie, Halle',
#    '@id': '0000-0003-4480-8661'},
#   {'@type': 'Person',
#    'givenName': 'Venkata Chandrasekhar',
#    'familyName': 'Nainala',
#    'email': 'chandu.nainala@uni-jena.de',
#    'affiliation': 'Friedrich-Schiller-Universität Jena',
#    '@id': '0000-0002-2564-3243'}],
#  'isAccessibleForFree': True,
#  'measurementTechnique': 'http://purl.obolibrary.org/obo/CHMO_0000613'}

# %% [markdown]
# ## Retrieve Bioschemas.org metadata by nmrXiv identifier
#
# Generates comprehensive Bioschemas.org compliant metadata for a specific scientific data entry identified by its public nmrXiv identifier. Returns structured metadata that enhances discoverability in scientific search engines, enables integration with knowledge graphs, and supports FAIR data principles. Includes detailed molecular representations, experimental methodologies, and semantic annotations using established scientific ontologies. Provide public model identifier for Project, Sample or Dataset e.g. `P10` for Project, `S70` for Sample or `D399` for Dataset.

# %%
public_id = "P971"
bioschema = bioschemas(public_id=public_id)
bioschema
# Out:
# GET https://dev.nmrxiv.org/api/v1/schemas/bioschemas/P971 -> 200
# {'@context': 'https://schema.org',
#  '@type': 'Study',
#  '@id': '10.82347/nmrxiv-dev.p971',
#  'dct:conformsTo': [{'@type': 'CreativeWork',
#    '@id': 'https://bioschemas.org/types/Study/0.3-DRAFT'},
#   {'@type': 'CreativeWork',
#    '@id': 'https://isa-specs.readthedocs.io/en/latest/isamodel.html#investigation'}],
#  'name': 'Project-test-Embargo',
#  'description': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore',
#  'keywords': ['nmr', 'diabetes', 'hellp', 'hello', 'nmr2'],
#  'license': 'https://cdla.dev/permissive-1-0/',
#  'publisher': {'@type': 'Organization',
#   'name': 'nmrXiv-dev',
#   'url': 'https://dev.nmrxiv.org'},
#  'url': 'https://dev.nmrxiv.org/P971',
#  'dateCreated': '2026-05-22T09:47:34.000000Z',
#  'dateModified': '2026-05-30T00:00:12.000000Z',
#  'datePublished': '2026-05-30T00:00:00.000000Z',
#  'author': [{'@type': 'Person',
#    'givenName': 'Nisha',
#    'familyName': 'Sharma',
#    'affiliation': 'Friedrich Schiller University Jena (FSU, Friedrich-Schiller-Universität Jena) - Education · Jena, Germany'}],
#  'citation': [{'@type': 'CreativeWork',
#    'author': 'Sakthidhasan Periasamy, Rajesh Ramasamy, Rajasekar Chinnaiyan, Arun Sridhar',
#    'headline': 'Machine Learning Integration of In-Silico QSAR, Graph Neural Networks and Docking Reveal Natural Products Inhibitors Against Mycobacterium tuberculosis',
#    '@id': '10.1000/journal.2023.0001'}],
#  'hasPart': [{'@type': 'Study',
#    '@id': '10.82347/nmrxiv-dev.p971.s987',
#    'dct:conformsTo': [{'@type': 'CreativeWork',
#      '@id': 'https://bioschemas.org/types/Study/0.3-DRAFT'},
#     {'@type': 'CreativeWork',
#      '@id': 'https://isa-specs.readthedocs.io/en/latest/isamodel.html#study'}],
#    'name': 'compound_01',
#    'keywords': [],
#    'license': 'https://cdla.dev/permissive-1-0/',
#    'url': 'https://dev.nmrxiv.org/S987',
#    'dateCreated': '2026-05-22T09:47:34.000000Z',
#    'dateModified': '2026-05-30T00:00:12.000000Z',
#    'datePublished': '2026-05-26T22:00:00.000000Z',
#    'about': {'@type': 'ChemicalSubstance',
#     '@id': '10.82347/nmrxiv-dev.p971.s987',
#     'dct:conformsTo': [{'@type': 'CreativeWork',
#       '@id': 'https://bioschemas.org/types/ChemicalSubstance/0.3-RELEASE-2019_09_02'}],
#     'name': 'compound_01_sample',
#     'url': 'https://dev.nmrxiv.org/S987',
#     'hasBioChemEntityPart': [{'@type': 'MolecularEntity',
#       '@id': 'UHOVQNZJYSORNB-UHFFFAOYSA-N',
#       'dct:conformsTo': [{'@type': 'CreativeWork',
#         '@id': 'https://bioschemas.org/types/MolecularEntity/0.3-RELEASE-2019_09_02'}],
#       'url': 'https://pubchem.ncbi.nlm.nih.gov/compound/241',
#       'inChI': 'InChI=1S/C6H6/c1-2-4-6-5-3-1/h1-6H',
#       'inChIKey': 'UHOVQNZJYSORNB-UHFFFAOYSA-N',
#       'iupacName': 'benzene',
#       'molecularFormula': 'C6H6',
#       'molecularWeight': 78.11,
#       'smiles': [None, None, 'C1=CC=CC=C1'],
#       'description': 'Percentage composition: 99.99%'}]},
#    'studyDomain': 'Chemistry',
#    'studySubject': 'Small molecules',
#    'hasPart': [None]}]}

# %% [markdown]
# ## Retrieve DataCite metadata schema by nmrXiv identifier
#
# Generates DataCite Metadata Schema 4.4 compliant metadata for a specific scientific data entry using its public NMRXIV identifier. This metadata enables DOI registration, academic citation, and integration with scholarly databases. The schema includes comprehensive research context, authorship details, funding information, and technical specifications required for proper research data citation and discovery in academic environments. Provide public model identifier for Project, Sample or Dataset e.g. `P10` for Project, `S70` for Sample or `D399` for Dataset.

# %%
datacite_metadata = datacite(P90843)
datacite_metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 datacite_metadata = datacite(P90843)
#       2 datacite_metadata
#
# NameError: name 'P90843' is not defined
